# %% [markdown]
# #Statistics Advance Part 1

# %% [markdown]
# 1. What is a random variable in probability theory?
#
# A random variable is a function that assigns a real number to each outcome of a random experiment. It quantifies outcomes and allows us to analyze them mathematically.
#
# 2. What are the types of random variables?
#
# There are two main types:
#
# Discrete Random Variable: Takes countable values (e.g., number of students).
#
# Continuous Random Variable: Takes values within a range (e.g., height, weight).
#
# 3. What is the difference between discrete and continuous distributions?
#
# Discrete Distributions describe probabilities of distinct, separate outcomes (e.g., number of heads in coin tosses).
#
# Continuous Distributions describe probabilities over continuous intervals, where exact probabilities for single points are 0.
#
# 4. What are probability distribution functions (PDF)?
#
# For discrete variables, it's the Probability Mass Function (PMF): gives probability for each value.
#
# For continuous variables, it's the Probability Density Function (PDF): defines a density over a range. Probabilities are found via integration:
#
# 𝑃
# (
# 𝑎
# <
# 𝑋
# <
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a<X<b)=∫
# a
# b
# ​
#  f(x)dx
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#
# CDF gives the probability that a random variable is less than or equal to a value:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
# F(x)=P(X≤x)
# PDF shows the likelihood of a variable in an interval. The CDF is the integral of the PDF.
#
# 6. What is a discrete uniform distribution?
#
# A discrete uniform distribution assigns equal probability to each outcome in a finite set.
# Example: Rolling a fair die (1 to 6) →
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# 6
# P(X=x)=
# 6
# 1
# ​
#
#
# 7. What are the key properties of a Bernoulli distribution?
# Only two outcomes: 1 (success) and 0 (failure).
#
# One trial with success probability
# 𝑝
# p.
#
# Mean =
# 𝑝
# p, Variance =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# p(1−p).
#
# 8. What is the binomial distribution, and how is it used in probability?
# Models the number of successes in n independent Bernoulli trials.
#
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# Used in quality control, survey responses, etc.
#
# 9. What is the Poisson distribution and where is it applied?
#
# Models the number of events in a fixed interval of time/space when events occur at a constant average rate
# 𝜆
# λ.
#
# Formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
#
# ​
#
# Used in modeling phone calls, accidents, arrivals, etc.
#
# 10. What is a continuous uniform distribution?
# Every outcome in a range [a, b] has equal probability.
#
# PDF:
#
# 𝑓
# (
# 𝑥
# )
# =
# 1
# 𝑏
# −
# 𝑎
# ,
# 𝑎
# ≤
# 𝑥
# ≤
# 𝑏
# f(x)=
# b−a
# 1
# ​
#  ,a≤x≤b
# 11. What are the characteristics of a normal distribution?
# Bell-shaped, symmetric.
#
# Mean = Median = Mode.
#
# Completely defined by mean
# 𝜇
# μ and standard deviation
# 𝜎
# σ.
#
# Area under the curve = 1.
#
# 12. What is the standard normal distribution, and why is it important?
# A normal distribution with mean
# 𝜇
# =
# 0
# μ=0, and
# 𝜎
# =
# 1
# σ=1.
#
# Used for calculating Z-scores and performing hypothesis tests and confidence intervals.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# The CLT states that the sampling distribution of the sample mean becomes approximately normal as the sample size increases, regardless of the original distribution.
#
# It's key for statistical inference using the normal distribution.
#
# 14. How does the Central Limit Theorem relate to the normal distribution?
# The CLT ensures that sample means are approximately normally distributed when sample size is large, allowing us to apply normal-based methods like Z-tests and confidence intervals.
#
# 15. What is the application of Z statistics in hypothesis testing?
# Z-tests are used when the population standard deviation is known.
#
# Commonly used to test:
#
# Population means
#
# Differences between means
#
# Proportions
#
# 16. How do you calculate a Z-score, and what does it represent?
# Formula:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# Represents how many standard deviations a value
# 𝑋
# X is from the mean.
#
# 17. What are point estimates and interval estimates in statistics?
# Point Estimate: A single value that estimates a parameter (e.g., sample mean).
#
# Interval Estimate: A range of values that likely contains the population parameter (e.g., confidence interval).
#
# 18. What is the significance of confidence intervals in statistical analysis?
# A confidence interval (CI) gives a range for a population parameter, along with a level of confidence (e.g., 95%) that the true parameter lies within that range.
#
# 19. What is the relationship between a Z-score and a confidence interval?
# The Z-score defines the margin of error in a confidence interval:
#
# CI
# =
# 𝑥
# ˉ
# ±
# 𝑍
# ⋅
# 𝜎
# 𝑛
# CI=
# x
# ˉ
#  ±Z⋅
# n
# ​
#
# σ
# ​
#
# 20. How are Z-scores used to compare different distributions?
#
# Z-scores standardize values, allowing comparison of scores from different distributions.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# Observations are independent.
#
# Sample size is large (typically
# 𝑛
# ≥
# 30
# n≥30).
#
# The population has a finite variance.
#
# 22. What is the concept of expected value in a probability distribution?
#
# The expected value (E[X]) is the theoretical mean or average of a random variable over many trials:
#
# 𝐸
# (
# 𝑋
# )
# =
# ∑
# 𝑥
# 𝑖
# 𝑃
# (
# 𝑥
# 𝑖
# )
# (discrete)
# ,
# 𝐸
# (
# 𝑋
# )
# =
# ∫
# 𝑥
# 𝑓
# (
# 𝑥
# )
# 𝑑
# 𝑥
# (continuous)
# E(X)=∑x
# i
# ​
#  P(x
# i
# ​
#  )(discrete),E(X)=∫xf(x)dx(continuous)
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#
# A probability distribution shows the likelihood of each outcome.
#
# The expected value is a weighted average of outcomes using those probabilities, showing what we expect on average over time.

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, binom, poisson

# 1. Simulate multiple samples from a normal distribution and verify CLT
sample_means = []
for _ in range(1000):
    sample = np.random.normal(loc=50, scale=10, size=30)
    sample_means.append(np.mean(sample))
plt.hist(sample_means, bins=30, density=True, edgecolor='black')
plt.title("<B5 Central Limit Theorem Verification")
plt.xlabel("Sample Mean")
plt.ylabel("Density")
plt.grid(True)
plt.show()

# 2. Plot standard normal distribution
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.plot(x, y)
plt.title("<*5 Standard Normal Distribution")
plt.xlabel("Z")
plt.ylabel("PDF")
plt.grid(True)
plt.show()

# 3. Generate binomial random variables and calculate probabilities
binomial_data = binom.rvs(n=10, p=0.5, size=1000)
prob = binom.pmf(5, n=10, p=0.5)
print("<E5 P(X=5) for Binomial(n=10, p=0.5):", prob)

# 4. Calculate Z-score and compare to standard normal distribution
x_value = 80
mean = 70
std_dev = 10
z_score = (x_value - mean) / std_dev
prob_standard = norm.cdf(z_score)
print("<5 Z-score:", z_score, "Cumulative probability:", prob_standard)

# 5. Hypothesis testing using Z-statistics
sample_mean = 72
population_mean = 70
std_dev = 10
n = 30
z = (sample_mean - population_mean) / (std_dev / np.sqrt(n))
p_value = 1 - norm.cdf(z)
print("<5 Z-statistic:", z, "P-value:", p_value)

# 6. Confidence interval for dataset
data = np.random.normal(100, 15, 50)
mean_data = np.mean(data)
std_error = np.std(data, ddof=1) / np.sqrt(len(data))
margin = 1.96 * std_error
conf_int = (mean_data - margin, mean_data + margin)
print("9\"5 95% Confidence Interval:", conf_int)

# 7. Confidence interval from generated normal data
sample = np.random.normal(loc=60, scale=8, size=40)
mean_s = np.mean(sample)
se = np.std(sample, ddof=1) / np.sqrt(len(sample))
margin_s = 1.96 * se
ci_s = (mean_s - margin_s, mean_s + margin_s)
print("9<5 Confidence Interval for Sample Mean:", ci_s)

# 8. PDF of a normal distribution
x_vals = np.linspace(60, 80, 100)
pdf_vals = norm.pdf(x_vals, loc=70, scale=5)
plt.plot(x_vals, pdf_vals)
plt.title("995 Normal Distribution PDF")
plt.xlabel("x")
plt.ylabel("PDF")
plt.grid(True)
plt.show()

# 9. CDF of Poisson distribution
cdf_poisson = poisson.cdf(np.arange(0, 10), mu=3)
plt.step(np.arange(0, 10), cdf_poisson, where='mid')
plt.title("9\x16  Poisson CDF (mu=3)")
plt.xlabel("k")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()

# 10. Continuous uniform variable and expected value
uniform_data = np.random.uniform(5, 15, 1000)
expected_val = np.mean(uniform_data)
print("9\x12 Expected Value of Uniform(5, 15):", expected_val)

# 11. Compare standard deviations of two datasets
set1 = np.random.normal(100, 5, 100)
set2 = np.random.normal(100, 15, 100)
std1 = np.std(set1)
std2 = np.std(set2)
plt.hist(set1, bins=20, alpha=0.5, label='Low SD')
plt.hist(set2, bins=20, alpha=0.5, label='High SD')
plt.title("9B5 Comparing Standard Deviations")
plt.legend()
plt.grid(True)
plt.show()
print("Standard Deviation Set1:", std1)
print("Standard Deviation Set2:", std2)

# 12. Range and IQR of a dataset
normal_sample = np.random.normal(50, 10, 100)
data_range = np.ptp(normal_sample)
q1 = np.percentile(normal_sample, 25)
q3 = np.percentile(normal_sample, 75)
iqr = q3 - q1
print("9*5 Range:", data_range, "IQR:", iqr)

# 13. Z-score normalization
z_normalized = (normal_sample - np.mean(normal_sample)) / np.std(normal_sample)
sns.histplot(z_normalized, kde=True)
plt.title("9E5 Z-score Normalization")
plt.xlabel("Z-score")
plt.grid(True)
plt.show()
# Out:
# <E5 P(X=5) for Binomial(n=10, p=0.5): 0.24609375000000003
# <5 Z-score: 1.0 Cumulative probability: 0.8413447460685429
# <5 Z-statistic: 1.0954451150103321 P-value: 0.13666083914614902
# 9"5 95% Confidence Interval: (np.float64(93.12441004188723), np.float64(100.79851088197658))
# 9<5 Confidence Interval for Sample Mean: (np.float64(54.83763092499373), np.float64(59.911531589370696))
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 9 Expected Value of Uniform(5, 15): 10.132743425021959
# Standard Deviation Set1: 4.836697998755825
# Standard Deviation Set2: 13.54881180447557
# 9*5 Range: 53.43187462647366 IQR: 15.138937736344438

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, binom, poisson





#Write a Python program to generate a random variable and display its value its python.
import numpy as np
random_value = np.random.rand()
print("Random value:", random_value)




#Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution python

from scipy.stats import bernoulli

def bernoulli_pdf(p, x):
    return bernoulli.pmf(x, p)

print("P(X=1) with p=0.7:", bernoulli_pdf(0.7, 1))


#Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

from scipy.stats import binom

data = binom.rvs(n=10, p=0.5, size=1000)
plt.hist(data, bins=np.arange(12)-0.5, edgecolor='black', density=True)
plt.title("Binomial Distribution (n=10, p=0.5)")
plt.xlabel("Number of Successes")
plt.ylabel("Probability")
plt.grid(True)
plt.show()


# Create a Poisson distribution and visualize it using Python

from scipy.stats import poisson

poisson_data = poisson.rvs(mu=3, size=1000)
plt.hist(poisson_data, bins=np.arange(10)-0.5, edgecolor='black', density=True)
plt.title("Poisson Distribution (lambda=3)")
plt.xlabel("Occurrences")
plt.ylabel("Probability")
plt.grid(True)
plt.show()


#Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

cdf_values = np.cumsum(probabilities)

plt.step(values, cdf_values, where='mid')
plt.title("CDF of Discrete Uniform Distribution")
plt.xlabel("Outcome")
plt.ylabel("Cumulative Probability")
plt.grid(True)
plt.show()


#Generate a continuous uniform distribution using NumPy and visualize it

from scipy.stats import uniform

continuous_data = uniform.rvs(loc=0, scale=1, size=1000)
plt.hist(continuous_data, bins=20, edgecolor='black', density=True)
plt.title("Continuous Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()


#Simulate data from a normal distribution and plot its histogram

from scipy.stats import norm

normal_data = norm.rvs(loc=0, scale=1, size=1000)
plt.hist(normal_data, bins=30, edgecolor='black', density=True)
plt.title("Normal Distribution Histogram")
plt.xlabel("Value")
plt.ylabel("Density")
plt.grid(True)
plt.show()


#Write a Python function to calculate Z-scores from a dataset and plot them

import seaborn as sns

def plot_z_scores(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    sns.histplot(z_scores, bins=30, kde=True)
    plt.title("Z-score Histogram")
    plt.xlabel("Z-score")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()
    return z_scores

z_scores = plot_z_scores(normal_data)


#Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

def clt_simulation(sample_size=30, num_samples=1000):
    means = []
    for _ in range(num_samples):
        sample = np.random.exponential(scale=2.0, size=sample_size)
        means.append(np.mean(sample))
    plt.hist(means, bins=30, edgecolor='black', density=True)
    plt.title("CLT Simulation from Exponential Distribution")
    plt.xlabel("Sample Mean")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

clt_simulation()
# Out:
# Random value: 0.3287590229131917
# P(X=1) with p=0.7: 0.7
